# %% [markdown]
# # Importiong The libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing CSV File To NoteBook

# %%
mart=pd.read_csv('C:/Users/aksha/Documents/wallmart.csv')

# %%
mart[:45]
# Out:
#     Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0       1  05-02-2010    1643690.90             0        42.31       2.572
# 1       1  12-02-2010    1641957.44             1        38.51       2.548
# 2       1  19-02-2010    1611968.17             0        39.93       2.514
# 3       1  26-02-2010    1409727.59             0        46.63       2.561
# 4       1  05-03-2010    1554806.68             0        46.50       2.625
# 5       1  12-03-2010    1439541.59             0        57.79       2.667
# 6       1  19-03-2010    1472515.79             0        54.58       2.720
# 7       1  26-03-2010    1404429.92             0        51.45       2.732
# 8       1  02-04-2010    1594968.28             0        62.27       2.719
# 9       1  09-04-2010    1545418.53             0        65.86       2.770
# 10      1  16-04-2010    1466058.28             0        66.32       2.808
# ...

# %%
mart[-45:]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6390     45  23-12-2011    1521957.99             0        42.27       3.389
# 6391     45  30-12-2011     869403.63             1        37.79       3.389
# 6392     45  06-01-2012     714081.05             0        35.88       3.422
# 6393     45  13-01-2012     676615.53             0        41.18       3.513
# 6394     45  20-01-2012     700392.21             0        31.85       3.533
# 6395     45  27-01-2012     624081.64             0        37.93       3.567
# 6396     45  03-02-2012     757330.95             0        42.96       3.617
# 6397     45  10-02-2012     803657.12             1        37.00       3.640
# 6398     45  17-02-2012     858853.75             0        36.85       3.695
# 6399     45  24-02-2012     753060.78             0        42.86       3.739
# 6400     45  02-03-2012     782796.01             0        41.55       3.816
# ...

# %% [markdown]
# # Iterating The Data

# %%
mart.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
mart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
mart.nunique()
# Out:
# Store             45
# Date             143
# Weekly_Sales    6435
# Holiday_Flag       2
# Temperature     3528
# Fuel_Price       892
# CPI             2145
# Unemployment     349
# dtype: int64

# %%
mart.shape
# Out:
# (6435, 8)

# %%
mart.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
 mart.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %% [markdown]
# # Sorting Columns

# %%
mart.sort_values('Weekly_Sales')
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 4619     33  03-12-2010     209986.25             0        52.82       3.041
# 4614     33  29-10-2010     213538.32             0        71.34       3.130
# 4675     33  30-12-2011     215359.21             1        51.60       3.428
# 4623     33  31-12-2010     219804.85             1        52.91       3.148
# 4671     33  02-12-2011     220060.35             0        59.12       3.701
# ...     ...         ...           ...           ...          ...         ...
# 1762     13  24-12-2010    3595903.20             0        34.90       2.846
# 527       4  23-12-2011    3676388.98             0        35.92       3.103
# 1333     10  24-12-2010    3749057.69             0        57.06       3.236
# 2763     20  24-12-2010    3766687.43             0        25.17       3.141
# 1905     14  24-12-2010    3818686.45             0        30.59       3.141
#
#              CPI  Unemployment
# ...

# %%
mart.sort_values('Temperature')
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 910       7  04-02-2011     558027.77             0        -2.06       3.011
# 3626     26  28-01-2011     817485.14             0         5.54       3.243
# 2336     17  07-01-2011    1083071.14             0         6.23       2.891
# 959       7  13-01-2012     593875.46             0         7.46       3.077
# 5628     40  28-01-2011     775910.43             0         9.51       3.243
# ...     ...         ...           ...           ...          ...         ...
# 1597     12  23-07-2010     912403.67             0        99.22       3.112
# 5315     38  23-07-2010     328336.85             0        99.22       3.112
# 4657     33  26-08-2011     237095.82             0        99.66       3.663
# 4707     33  10-08-2012     297753.49             0       100.07       3.811
# 4599     33  16-07-2010     280937.84             0       100.14       2.971
#
#              CPI  Unemployment
# ...

# %%
mart.iloc[4,2]
# Out:
# 1554806.68

# %%
mart.iloc[7,5]
# Out:
# 2.732

# %%
mart.iloc[9,5]
# Out:
# 2.77

# %%
mart.iloc[2,7]
# Out:
# 8.106

# %%
mart.iloc[11,6]
# Out:
# 210.4391228

# %% [markdown]
# # Checking Data For NULL Values

# %%
mart.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
mart.notnull().sum()
# Out:
# Store           6435
# Date            6435
# Weekly_Sales    6435
# Holiday_Flag    6435
# Temperature     6435
# Fuel_Price      6435
# CPI             6435
# Unemployment    6435
# dtype: int64

# %% [markdown]
# # Changing Dtype of column in datasets

# %%
mart.Temperature.astype(int)
# Out:
# 0       42
# 1       38
# 2       39
# 3       46
# 4       46
#         ..
# 6430    64
# 6431    64
# 6432    54
# 6433    56
# 6434    58
# Name: Temperature, Length: 6435, dtype: int32

# %%
mart.Weekly_Sales.astype(int)
# Out:
# 0       1643690
# 1       1641957
# 2       1611968
# 3       1409727
# 4       1554806
#          ...
# 6430     713173
# 6431     733455
# 6432     734464
# 6433     718125
# 6434     760281
# Name: Weekly_Sales, Length: 6435, dtype: int32

# %%
mart.Fuel_Price.astype(int)[--40:]
# Out:
# 40      2
# 41      2
# 42      2
# 43      2
# 44      2
#        ..
# 6430    3
# 6431    3
# 6432    4
# 6433    3
# 6434    3
# Name: Fuel_Price, Length: 6395, dtype: int32

# %% [markdown]
# # Counting Values Of Items

# %%
mart['Holiday_Flag'].value_counts()
# Out:
# 0    5985
# 1     450
# Name: Holiday_Flag, dtype: int64

# %%
mart['Date'].value_counts()
# Out:
# 07-09-2012    45
# 08-10-2010    45
# 18-06-2010    45
# 28-05-2010    45
# 23-09-2011    45
#               ..
# 14-10-2011    45
# 09-03-2012    45
# 06-08-2010    45
# 29-04-2011    45
# 22-04-2011    45
# Name: Date, Length: 143, dtype: int64

# %% [markdown]
# # Visualising The Dataset

# %% [markdown]
# # A)PAIRPLOT

# %%
sns.pairplot(mart)

# %% [markdown]
# # B)HEATMAP

# %%
sns.heatmap(mart.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # C)COUNTPLOT

# %%
sns.set_style('whitegrid')
sns.countplot(x="Holiday_Flag", data=mart,palette = "Set2");

# %% [markdown]
# # D)HISTPLOT

# %%
sns.histplot(mart['Temperature'],kde = False)
plt.show()

# %%
sns.histplot(mart['Weekly_Sales'],kde = False)
plt.show()

# %%
sns.histplot(mart['Fuel_Price'],kde = False)
plt.show()

# %%
sns.histplot(mart['CPI'],kde = False)
plt.show()

# %%
sns.histplot(mart['Unemployment'],kde = False)
plt.show()

# %% [markdown]
# # E)SCATTERPLOT

# %%
sns.scatterplot(x='Holiday_Flag', y='Unemployment', data= mart, marker = '+')
# Out:
# <AxesSubplot:xlabel='Holiday_Flag', ylabel='Unemployment'>

# %% [markdown]
# # F)JOINTPLOT

# %%
sns.jointplot(data=mart, x="Weekly_Sales", y="Fuel_Price")

# %%
sns.jointplot(data=mart, x="Weekly_Sales", y="CPI")

# %% [markdown]
# # G)KDEPLOT

# %%
sns.kdeplot(data=mart, x="Fuel_Price")
# Out:
# <AxesSubplot:xlabel='Fuel_Price', ylabel='Density'>

# %%
sns.kdeplot(data=mart, x="Weekly_Sales")
# Out:
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %%
sns.kdeplot(data=mart, x="Temperature")
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Density'>

# %%
sns.kdeplot(data=mart, x="CPI")
# Out:
# <AxesSubplot:xlabel='CPI', ylabel='Density'>

# %%
sns.kdeplot(data=mart, x="Unemployment",hue="Holiday_Flag")
# Out:
# <AxesSubplot:xlabel='Unemployment', ylabel='Density'>

# %% [markdown]
# # H)REGPLOT

# %%
sns.regplot(x="Store", y="Unemployment", data=mart,color="red")
# Out:
# <AxesSubplot:xlabel='Store', ylabel='Unemployment'>

# %% [markdown]
# # I)PIECHART

# %%
y = ([5985,450])
HolidayFlags= ["ZEROS","ONES"]

plt.pie(y, labels = HolidayFlags,radius=1.5,autopct='%0.1f%%')
plt.legend()
plt.show()
